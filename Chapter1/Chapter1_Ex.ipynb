# %% [markdown]
# ## **Chapter 1: Tổng quan R**
# **Exercise 1:**
# Viết chương trình tính tổng, hiệu, tích, thương của 2 số a và b (với giá trị tùy chọn). In kết quả

# %%
a = 20
b = 10

tong = a + b
hieu = a - b
tich = a * b
thuong = a/b

# %%
print(paste("a =", a))
print(paste("b =",b))
# Out:
# [1] "a = 20"
# [1] "b = 10"

# %%
print(paste("Tong = ", tong))
print(paste("Hieu = ", hieu))
print(paste("Tich = ", tich))
print(paste("Thuong = ", thuong))
# Out:
# [1] "Tong =  30"
# [1] "Hieu =  10"
# [1] "Tich =  200"
# [1] "Thuong =  2"
