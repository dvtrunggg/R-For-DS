# %% [markdown]
# ## **Chapter 5: Functions**

# %%
# https://drive.google.com/file/d/1QUCIUhLhTUIHOSCE8_JBcZNyQXoQiifn/view?usp=sharing
system('gdown --id 1QUCIUhLhTUIHOSCE8_JBcZNyQXoQiifn')
source('ex_functions.R')

# %% [markdown]
# ### **Exercise 1: Tính BMI và đánh giá**

# %%
# tinh bmi
bmi_1.function <- function(height, weight){
    bmi <- weight/(height * height)
    return(bmi)
}

# %%
danh_gia_bmi_1.function <- function(bmi){
    result <-""
    if(bmi < 18.5){
        result <- "Gay"
    }else if(bmi<25){
        result <- "Binh thuong"
    }else{
        result <- "Thua can"
    }
    return(result)
}

# %%
height <- as.numeric(readline(prompt = "Input height (m): "))
weight <- as.numeric(readline(prompt = "Input weight (kg): "))

bmi <- bmi_1.function(height, weight)
danh_gia <- danh_gia_bmi_1.function(bmi) 

print(paste("BMI: ",bmi))
print(paste("Ket qua: ",danh_gia))
# Out:
# Input height (m): 1.73
# Input weight (kg): 64
# [1] "BMI:  21.3839419960573"
# [1] "Ket qua:  Binh thuong"

# %%
bmi <- bmi.function(1.73, 64)
danh_gia <- danh_gia_bmi.function(bmi)

print(paste("BMI: ",bmi))
print(paste("Ket qua: ",danh_gia))
# Out:
# [1] "BMI:  21.3839419960573"
# [1] "Ket qua:  Binh thuong"

# %% [markdown]
# ### **Exercise 2**
# - Giải phương trình bậc 1

# %%
ptb1.function <- function(a,b){
    result <- ""
    if(a==0 & b!=0){
        result <- "PT vo nghiem"
    }else if(a==0 & b==0){
        result <- "PT vo so nghiem"
    }else{
        result <- paste("Nghiem:", -b/a)
    }
    return(result)
}

# %%
a <- as.numeric(readline(prompt = "Input a: "))
b <- as.numeric(readline(prompt = "Input b: "))
result = ptb1.function(a,b) 

print(paste(a,"x +",b,"= 0 => ",result))
# Out:
# Input a: 10
# Input b: 20
# [1] "10 x + 20 = 0 =>  Nghiem: -2"

# %% [markdown]
# - Giải phương trình bậc 2

# %%
# giai PT bac 2
ptb2.function <- function(a,b,c){
    result <- ""
    # khi a == 0 => giai PTB1
    if(a==0){
        result <- ptb1.function(b,c)
    }else{
        # giai PTB2
        delta <- b*b - 4*a*c
        if(delta<0){
            result <- "Phuong trinh vo nghiem"
        } else if(delta==0){
            nghiem <- -b/(2*a)
            result <- paste("x1 = x2 = x0 =", nghiem)
        } else{
            x1 <- (-b + sqrt(delta))/(2*a)
            x2 <- (-b - sqrt(delta))/(2*a)
            result <- paste("x1 =", x1, ", x2 =", x2)
        }
    }
    return(result)
}

# %%
a <- as.numeric(readline(prompt = "Input a: "))
b <- as.numeric(readline(prompt = "Input b: "))
c <- as.numeric(readline(prompt = "Input c: "))

result = ptb2.function(a,b,c) 
print(paste(a,"x^2 +",b,"x +",c, "= 0 => ",result))
# Out:
# Input a: 2
# Input b: 6
# Input c: 10
# [1] "2 x^2 + 6 x + 10 = 0 =>  Phuong trinh vo nghiem"

# %% [markdown]
# ### **Exercise 3: Xây dựng function**
# - Hãy xây dựng các function: tinh_tien_dien.function, kiem_tra_SNT.function,
# tinh_cuoc_xe.function, ... dựa trên các bài tập đã làm
# - Gọi sử dụng các function này => In kết quả

# %%
so_kw <- as.integer(readline(prompt = "So kw tieu thu: "))
# Out:
# So kw tieu thu: 200

# %%
tien_dien = tinh_tien_dien.function(200)
print(paste("Tien dien:", tien_dien, "VND"))
# Out:
# [1] "Tien dien: 329450 VND"

# %%
# Kiem tra so nguyen to
n <- as.integer(readline(prompt = "Nhap n: "))
# Out:
# Nhap n: 300

# %%
test = isPrime(n)

print(paste(n, if (test) "is Prime" else "is not Prime"))
# Out:
# [1] "300 is not Prime"

# %%
test = isPrime(13)

print(paste(13, if (test) "is Prime" else "is not Prime"))
# Out:
# [1] "13 is Prime"
