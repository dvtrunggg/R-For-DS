# %% [markdown]
# ## **Chapter 2 - R cơ bản**

# %% [markdown]
# ### **Exercise 1: Thông tin cá nhân**

# %%
mark <- 6

# %%
name <- readline(prompt="Enter name: ")

yob <- readline(prompt="Enter year of birth: ")
yob <- as.integer(yob)

height <- readline(prompt="Enter heigh: ")
height <- as.double(height)

weight <- readline(prompt="Enter weight: ")
weight <- as.double(weight)
# Out:
# Enter name: Trung
# Enter year of birth: 1999
# Enter heigh: 1.73
# Enter weight: 64

# %%
bmi = weight/(height^2)

print(paste("Name:", name, ", Year of Birth:", yob))
print(paste("Height:", round(height,2), "(m), Weigth:", round(weight,2), "(kg), BMI: ", round(bmi,2)))
# Out:
# [1] "Name: Trung , Year of Birth: 1999"
# [1] "Height: 1.73 (m), Weigth: 64 (kg), BMI:  21.38"

# %% [markdown]
# ### **Exercise 2: Tính tiền hóa đơn ăn uống**

# %%
sum_of_food_and_drink <- readline(prompt="Total of foods and drinks: ")
sum_of_food_and_drink <- as.integer(sum_of_food_and_drink)

tax <- readline(prompt="Tax (10-20 %): ")
tax <- as.integer(tax)

tip <- readline(prompt="Tip (5-10 %)/:")
tip <- as.integer(tip)
# Out:
# Total of foods and drinks: 100
# Tax (10-20 %): 15
# Tip (5-10 %)/:5

# %%
tax.m = sum_of_food_and_drink * tax/100
tip.m = sum_of_food_and_drink * tip/100

total = sum_of_food_and_drink + tax.m + tip.m
total
# Out:
# [1] 120

# %%
print(paste("Total of foods and drinks: ", sum_of_food_and_drink, "VND"))
print(paste("Tax: ", tax.m, "VND"))
print(paste("Tip: ", tip.m, "VND"))
print(paste("You need to pay (total): ", format(total,scientific = FALSE), "VND"))
# Out:
# [1] "Total of foods and drinks:  100 VND"
# [1] "Tax:  15 VND"
# [1] "Tip:  5 VND"
# [1] "You need to pay (total):  120 VND"

# %% [markdown]
# ### **Exercise 3: Tính tiền lãi gửi tiết kiệm**

# %%
lai_suat_nam <- readline(prompt = "Input interest rate/year (%): ")
lai_suat_nam <- as.numeric(lai_suat_nam)
so_tien_1 <- readline(prompt = "Input amount of money:")
so_tien <- as.numeric(so_tien_1)
so_ngay_gui <- readline(prompt = "Input number of days:")
so_ngay_gui <- as.integer(so_ngay_gui)
# Out:
# Input interest rate/year (%): 10
# Input amount of money:100000000
# Input number of days:650

# %%
lai_suat_ngay = (lai_suat_nam/365)/100
tien_lai = so_tien * lai_suat_ngay * so_ngay_gui
tien_gui_va_lai = so_tien + tien_lai

# %%
result = paste("Interest rate/day: ", lai_suat_ngay,
            "\nAmount of money: ", so_tien_1, " after ", so_ngay_gui,
            " days => Saving interest money: ", round(tien_lai,2),
            "\nSum:",
            format(tien_gui_va_lai, big.mark=".", decimal.mark = ",", 
            nsmall = 2),sep=""
)

cat(result)
# Out:
# Interest rate/day: 0.000273972602739726
# Amount of money: 100000000 after 650 days => Saving interest money: 17808219.18
# Sum:117.808.219,18

# %% [markdown]
# ### **Exercise 4: Tính bán kính và chu vi hình tròn**

# %%
S <- readline(prompt = "Input S of cricle:")
S <- as.double(S)
# Out:
# Input S of cricle:100

# %%
PI <- 3.14
R <- sqrt(S/PI)
P <- 2 * PI * R

# %%
print(paste("R of circle:", round(R,2)))
print(paste("P of circle:", round(P,2)))
# Out:
# [1] "R of circle: 5.64"
# [1] "P of circle: 35.44"

# %% [markdown]
# ### **Exercise 5: Làm việc với chuỗi**

# %%
str1 <- readline(prompt = "Input s1:")
str2 <- readline(prompt = "Input s2:")
str3 <- readline(prompt = "Input s3:")

index <- as.integer(readline(prompt = "Input index:"))
str_find <- readline(prompt = "Find_string:")
str_replace <- readline(prompt = "Replace_string:")
# Out:
# Input s1:viết gì nhỉ
# Input s2:buồn ngủ quá
# Input s3:je dois dormir
# Input index:2
# Find_string:ngủ
# Replace_string:miệng

# %%
str4 <- substring(str1,index)
str5 <- substring(str1, 1, index)

# thay the 1 chuoi voi 1 chuoi dau tien thoa
str_new <-sub(str_find, str_replace, str1)

#thay the 1 chuoi cho tat ca cac chuoi thoa
str_new <-gsub(str_find, str_replace, str1)

# %%
print(paste("str4 (index ->):", str4))
print(paste("str5 (->index):", str5))
print(paste("Lenght of str1:", nchar(str1), 
            ", Length of str2:", nchar(str2), 
            ", Length of str3:", nchar(str3)))
print(paste("After replace:", str_new))
# Out:
# [1] "str4 (index ->): iết gì nhỉ"
# [1] "str5 (->index): vi"
# [1] "Lenght of str1: 11 , Length of str2: 12 , Length of str3: 14"
# [1] "After replace: viết gì nhỉ"

# %% [markdown]
# ### **Exercise 6: Khoảng cách giữa 2 ngày**

# %%
date_1 <- readline(prompt = "Input date: dd-mm-YYYY:")
date_1 <- as.Date(date_1, format("%d-%m-%Y"))
# Out:
# Input date: dd-mm-YYYY:10-2-2019

# %%
now_date <- Sys.Date()
distance <- now_date - date_1

# %%
print(paste("Input date:", date_1))
print(paste("Now:", now_date))
print(paste("Distance between", now_date, "and", date_1, "is", distance))
# Out:
# [1] "Input date: 2019-02-10"
# [1] "Now: 2022-04-03"
# [1] "Distance between 2022-04-03 and 2019-02-10 is 1148"

# %% [markdown]
# ### **Exercise 7: Bảy ngày tiếp theo**

# %%
date_str <- readline(prompt = "Input your date dd-mm-YYYY:")
date_1 <- as.Date(date_str, format("%d-%m-%Y"))
# Out:
# Input your date dd-mm-YYYY:10-5-2021

# %%
if(is.na(date_1)){
    print(paste(date_str, "Can not create a date"))
}else{
    print(paste(date_1, "is", weekdays.Date(date_1))) 
    seven_days <- seq(date_1, length = 7, by = 1)
    print(paste("7 continuing days:",toString(seven_days)))
}
# Out:
# [1] "2021-05-10 is Monday"
# [1] "7 continuing days: 2021-05-10, 2021-05-11, 2021-05-12, 2021-05-13, 2021-05-14, 2021-05-15, 2021-05-16"
